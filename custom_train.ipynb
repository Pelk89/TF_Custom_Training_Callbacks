# %%
{}

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import time
from custom_callbacks import TFCallbacks as tfc

# %%
{}

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value


@tf.function
def test_step(x, y):
    val_logits = model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
# Instantiate an optimizer.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the training dataset.
batch_size = 64
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
# Get model
inputs = keras.Input(shape=(784,), name="digits")
x = layers.Dense(64, activation="relu", name="dense_1")(inputs)
x = layers.Dense(64, activation="relu", name="dense_2")(x)
outputs = layers.Dense(10, name="predictions")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# Instantiate an optimizer to train the model.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the metrics.
train_acc_metric = keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = keras.metrics.SparseCategoricalAccuracy()

# Prepare the training dataset.
batch_size = 64
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
# Reserve 10,000 samples for validation.
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %%
reduce_rl_plateau = tfc.RRLoP(patience=epochs, 
                              verbose=1, 
                              optim_lr=optimizer.learning_rate, 
                              r_expo=True, factor=0.1)

epochs = 15

# %%
##
reduce_rl_plateau.train_begin()
for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))
    start_time = time.time()

    # Iterate over the batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        loss_value = train_step(x_batch_train, y_batch_train)

        # Log every 200 batches.
        if step % 200 == 0:
            print(
                "Training loss (for one batch) at step %d: %.4f"
                % (step, float(loss_value))
            )
            print("Seen so far: %d samples" % ((step + 1) * 64))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()
    print("Training acc over epoch: %.4f" % (float(train_acc),))

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in val_dataset:
        test_step(x_batch_val, y_batch_val)

    val_acc = val_acc_metric.result()
    val_acc_metric.reset_states()

    val_loss_results.append(val_acc)

    print("Validation acc: %.4f" % (float(val_acc),))
    # print("Time taken: %.2fs" % (time.time() - start_time))
    ##
    reduce_rl_plateau.epoch_end(epoch,val_acc)
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 0.1194
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2216
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1957
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1935
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0408
# Seen so far: 51264 samples
# Training acc over epoch: 0.9507
# Validation acc: 0.9561
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.2143
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.0973
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2655
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2845
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3768
# Seen so far: 51264 samples
# Training acc over epoch: 0.9507
# Validation acc: 0.9562
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.4162
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1379
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2169
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1420
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2100
# Seen so far: 51264 samples
# Training acc over epoch: 0.9506
# Validation acc: 0.9563
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.1234
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2288
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1827
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2388
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0991
# Seen so far: 51264 samples
# Training acc over epoch: 0.9507
# Validation acc: 0.9560
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.1802
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1248
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1474
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.0995
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1695
# Seen so far: 51264 samples
# Training acc over epoch: 0.9509
# Validation acc: 0.9562
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.2630
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1093
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1800
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1126
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1306
# Seen so far: 51264 samples
# Training acc over epoch: 0.9509
# Validation acc: 0.9561
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.1785
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1127
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1612
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3465
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1958
# Seen so far: 51264 samples
# Training acc over epoch: 0.9509
# Validation acc: 0.9562
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.1698
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1796
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1143
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4063
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1399
# Seen so far: 51264 samples
# Training acc over epoch: 0.9509
# Validation acc: 0.9567
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.2248
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1913
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2207
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3417
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0804
# Seen so far: 51264 samples
# Training acc over epoch: 0.9510
# Validation acc: 0.9562
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.0980
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2027
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1730
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1887
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1288
# Seen so far: 51264 samples
# Training acc over epoch: 0.9512
# Validation acc: 0.9564
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.1664
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.0971
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.0887
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.0691
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2456
# Seen so far: 51264 samples
# Training acc over epoch: 0.9510
# Validation acc: 0.9569
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.1284
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1944
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2043
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2112
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1353
# Seen so far: 51264 samples
# Training acc over epoch: 0.9510
# Validation acc: 0.9564
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.0531
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1492
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1898
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2695
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1976
# Seen so far: 51264 samples
# Training acc over epoch: 0.9511
# Validation acc: 0.9567
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.1662
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1368
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2168
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1856
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0495
# Seen so far: 51264 samples
# Training acc over epoch: 0.9513
# Validation acc: 0.9569
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.0681
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.0809
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1173
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2033
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0649
# Seen so far: 51264 samples
# Training acc over epoch: 0.9513
# Validation acc: 0.9569
