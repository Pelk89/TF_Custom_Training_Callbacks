# %%
{}
## Tensorflow Custom Training with Custom Callbacks
# Custom Training & Evaluation based on https://keras.io/guides/writing_a_training_loop_from_scratch/
# Reduce learning rate on plateau based on https://keras.io/api/callbacks/reduce_lr_on_plateau/
## Tutorial by Alexander Pelkmann 2021 
# Linkedin --> https://www.linkedin.com/in/alexander-pelkmann
# Github --> https://github.com/Pelk89
# Medium --> https://medium.com/@alexander.pelkmann
# Out:
# {}

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

## Custom Modification: import custom reduce learning rate on plateau callback
from custom_callback import CustomReduceLRoP

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value


@tf.function
def test_step(x, y):
    val_logits = model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
# Instantiate an optimizer.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the training dataset.
batch_size = 64
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
# Get model
inputs = keras.Input(shape=(784,), name="digits")
x = layers.Dense(64, activation="relu", name="dense_1")(inputs)
x = layers.Dense(64, activation="relu", name="dense_2")(x)
outputs = layers.Dense(10, name="predictions")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# Instantiate an optimizer to train the model.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the metrics.
train_acc_metric = keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = keras.metrics.SparseCategoricalAccuracy()

# Prepare the training dataset.
batch_size = 64
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
# Reserve 10,000 samples for validation.
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %%
## Custom Modification: Set reduce_lin true for linear reducing; Set factor to reduce learning rate by 0.0001

reduce_rl_plateau = CustomReduceLRoP(patience=2,
                              factor=0.0001,
                              verbose=1, 
                              optim_lr=optimizer.learning_rate, 
                              reduce_lin=True)

# %%
epochs = 15

## Custom Modification: Reset cooldown and wait timer for the callback
reduce_rl_plateau.on_train_begin()

for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))

    # Iterate over the batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        loss_value = train_step(x_batch_train, y_batch_train)

        # Log every 200 batches.
        if step % 200 == 0:
            print(
                "Training loss (for one batch) at step %d: %.4f"
                % (step, float(loss_value))
            )
            print("Seen so far: %d samples" % ((step + 1) * 64))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()
    print("Training acc over epoch: %.4f" % (float(train_acc),))

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in val_dataset:
        test_step(x_batch_val, y_batch_val)

    val_acc = val_acc_metric.result()
    val_acc_metric.reset_states()

 
    print("Validation acc: %.4f" % (float(val_acc),))

    ## Custom Modification: pass epoch and validation loss to the callback 
    reduce_rl_plateau.on_epoch_end(epoch, val_acc)
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 0.1810
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4180
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1071
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3425
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.4618
# Seen so far: 51264 samples
# Training acc over epoch: 0.9338
# Validation acc: 0.9436
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.2813
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3964
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.0183
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1256
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0428
# Seen so far: 51264 samples
# Training acc over epoch: 0.9345
# Validation acc: 0.9448
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.2022
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2111
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1531
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1135
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1687
# Seen so far: 51264 samples
# Training acc over epoch: 0.9350
# Validation acc: 0.9454
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.3467
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5183
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2738
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2378
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1909
# Seen so far: 51264 samples
# Training acc over epoch: 0.9356
# Validation acc: 0.9456
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.1785
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4341
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3431
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3445
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1361
# Seen so far: 51264 samples
# Training acc over epoch: 0.9366
# Validation acc: 0.9460
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.1684
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3109
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4974
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1582
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1732
# Seen so far: 51264 samples
# Training acc over epoch: 0.9370
# Validation acc: 0.9465
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.1088
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2453
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2171
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3069
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.0755
# Seen so far: 51264 samples
# Training acc over epoch: 0.9381
# Validation acc: 0.9468
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.4338
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1983
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2034
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1745
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2525
# Seen so far: 51264 samples
# Training acc over epoch: 0.9385
# Validation acc: 0.9471
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.1177
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1928
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2282
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1504
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2932
# Seen so far: 51264 samples
# Training acc over epoch: 0.9391
# Validation acc: 0.9475
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.3209
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2635
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2899
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1886
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3061
# Seen so far: 51264 samples
# Training acc over epoch: 0.9397
# Validation acc: 0.9478
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.1633
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2351
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3689
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1385
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1288
# Seen so far: 51264 samples
# Training acc over epoch: 0.9405
# Validation acc: 0.9473
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002000000142492354.
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.1252
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2983
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2734
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2759
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2487
# Seen so far: 51264 samples
# Training acc over epoch: 0.9412
# Validation acc: 0.9470
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.1236
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1272
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2770
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1983
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1529
# Seen so far: 51264 samples
# Training acc over epoch: 0.9416
# Validation acc: 0.9478
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.1871
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2503
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2498
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1926
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1604
# Seen so far: 51264 samples
# Training acc over epoch: 0.9417
# Validation acc: 0.9478
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.1757
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1776
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1526
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1889
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1596
# Seen so far: 51264 samples
# Training acc over epoch: 0.9419
# Validation acc: 0.9480
