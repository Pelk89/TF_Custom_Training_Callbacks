# %%
{}
## Tensorflow Custom Training with Custom Callbacks
# Custom Training & Evaluation based on https://keras.io/guides/writing_a_training_loop_from_scratch/
# Reduce learning rate on plateau based on https://keras.io/api/callbacks/reduce_lr_on_plateau/
## Tutorial by Alexander Pelkmann 2021 
# Linkedin --> https://www.linkedin.com/in/alexander-pelkmann
# Github --> https://github.com/Pelk89
# Medium --> https://medium.com/@alexander.pelkmann
# Out:
# {}

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

## Custom Modification: import custom reduce learning rate on plateau callback
from custom_callback import CustomReduceLRoP

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value


@tf.function
def test_step(x, y):
    val_logits = model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
# Instantiate an optimizer.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the training dataset.
batch_size = 64
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
# Get model
inputs = keras.Input(shape=(784,), name="digits")
x = layers.Dense(64, activation="relu", name="dense_1")(inputs)
x = layers.Dense(64, activation="relu", name="dense_2")(x)
outputs = layers.Dense(10, name="predictions")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# Instantiate an optimizer to train the model.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the metrics.
train_acc_metric = keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = keras.metrics.SparseCategoricalAccuracy()

# Prepare the training dataset.
batch_size = 64
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
# Reserve 10,000 samples for validation.
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %%
## Custom Modification: Set reduce_lin true for linear reducing; Set factor to reduce learning rate by 0.0001

reduce_rl_plateau = CustomReduceLRoP(patience=2,
                              factor=0.0001,
                              verbose=1, 
                              optim_lr=optimizer.learning_rate, 
                              reduce_lin=True)

# %%
epochs = 15

## Custom Modification: Reset cooldown and wait timer for the callback
reduce_rl_plateau.on_train_begin()

for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))

    # Iterate over the batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        loss_value = train_step(x_batch_train, y_batch_train)

        # Log every 200 batches.
        if step % 200 == 0:
            print(
                "Training loss (for one batch) at step %d: %.4f"
                % (step, float(loss_value))
            )
            print("Seen so far: %d samples" % ((step + 1) * 64))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()
    print("Training acc over epoch: %.4f" % (float(train_acc),))

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in val_dataset:
        test_step(x_batch_val, y_batch_val)

    val_acc = val_acc_metric.result()
    val_acc_metric.reset_states()

 
    print("Validation acc: %.4f" % (float(val_acc),))

    ## Custom Modification: pass epoch and validation loss to the callback 
    reduce_rl_plateau.on_epoch_end(epoch, val_acc)
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 86.6014
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 2.1193
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.5417
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 1.0198
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.7340
# Seen so far: 51264 samples
# Training acc over epoch: 0.7162
# Validation acc: 0.8305
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.4859
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.6858
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3863
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.7630
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.6786
# Seen so far: 51264 samples
# Training acc over epoch: 0.8455
# Validation acc: 0.8917
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.4734
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5609
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3177
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.6571
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2256
# Seen so far: 51264 samples
# Training acc over epoch: 0.8751
# Validation acc: 0.9058
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0009000000474974513.
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.3562
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2290
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3710
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3013
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.5243
# Seen so far: 51264 samples
# Training acc over epoch: 0.8911
# Validation acc: 0.9154
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.2449
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5360
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2812
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3706
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3435
# Seen so far: 51264 samples
# Training acc over epoch: 0.9016
# Validation acc: 0.9242
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0008000000427477061.
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.3380
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2416
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3177
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4355
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2277
# Seen so far: 51264 samples
# Training acc over epoch: 0.9089
# Validation acc: 0.9273
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.3565
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3865
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2553
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3181
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3294
# Seen so far: 51264 samples
# Training acc over epoch: 0.9145
# Validation acc: 0.9280
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.000700000037997961.
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.1502
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2344
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1956
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2096
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2129
# Seen so far: 51264 samples
# Training acc over epoch: 0.9186
# Validation acc: 0.9339
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.1710
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2923
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3988
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2757
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1513
# Seen so far: 51264 samples
# Training acc over epoch: 0.9230
# Validation acc: 0.9362
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0006000000332482159.
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.0635
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2085
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3292
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2384
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1225
# Seen so far: 51264 samples
# Training acc over epoch: 0.9246
# Validation acc: 0.9386
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.2795
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5251
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2779
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3488
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1172
# Seen so far: 51264 samples
# Training acc over epoch: 0.9274
# Validation acc: 0.9392
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000284984707.
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.2685
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2822
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2062
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2718
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3202
# Seen so far: 51264 samples
# Training acc over epoch: 0.9294
# Validation acc: 0.9420
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.0989
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3126
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1859
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2265
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2198
# Seen so far: 51264 samples
# Training acc over epoch: 0.9310
# Validation acc: 0.9426
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00040000002374872566.
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.1962
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2372
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1184
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3306
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2349
# Seen so far: 51264 samples
# Training acc over epoch: 0.9322
# Validation acc: 0.9442
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.2259
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2364
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3143
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2551
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.4840
# Seen so far: 51264 samples
# Training acc over epoch: 0.9335
# Validation acc: 0.9459
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00030000001899898053.
