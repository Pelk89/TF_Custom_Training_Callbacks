# %%
{}
## Tensorflow Custom Training with Custom Callbacks
# Custom Training & Evaluation based on https://keras.io/guides/writing_a_training_loop_from_scratch/
# Reduce learning rate on plateau based on https://keras.io/api/callbacks/reduce_lr_on_plateau/
## Tutorial by Alexander Pelkmann 2021 
# Linkedin --> https://www.linkedin.com/in/alexander-pelkmann
# Github --> https://github.com/Pelk89
# Medium --> https://medium.com/@alexander.pelkmann
# Out:
# {}

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

## Custom Modification: import custom reduce learning rate on plateau callback
from custom_callback import CustomReduceLRoP

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value


@tf.function
def test_step(x, y):
    val_logits = model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
# Instantiate an optimizer.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the training dataset.
batch_size = 64
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
# Get model
inputs = keras.Input(shape=(784,), name="digits")
x = layers.Dense(64, activation="relu", name="dense_1")(inputs)
x = layers.Dense(64, activation="relu", name="dense_2")(x)
outputs = layers.Dense(10, name="predictions")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# Instantiate an optimizer to train the model.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the metrics.
train_acc_metric = keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = keras.metrics.SparseCategoricalAccuracy()

# Prepare the training dataset.
batch_size = 64
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
# Reserve 10,000 samples for validation.
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %%
## Custom Modification:

reduce_rl_plateau = CustomReduceLRoP(patience=10, 
                              verbose=1, 
                              optim_lr=optimizer.learning_rate, 
                              r_expo=True)

# %%
epochs = 15

## Custom Modification: Reset cooldown and wait timer for the callback
reduce_rl_plateau.on_train_begin()

for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))

    # Iterate over the batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        loss_value = train_step(x_batch_train, y_batch_train)

        # Log every 200 batches.
        if step % 200 == 0:
            print(
                "Training loss (for one batch) at step %d: %.4f"
                % (step, float(loss_value))
            )
            print("Seen so far: %d samples" % ((step + 1) * 64))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()
    print("Training acc over epoch: %.4f" % (float(train_acc),))

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in val_dataset:
        test_step(x_batch_val, y_batch_val)

    val_acc = val_acc_metric.result()
    val_acc_metric.reset_states()

 
    print("Validation acc: %.4f" % (float(val_acc),))

    ## Custom Modification: pass epoch and validation loss to the callback 
    reduce_rl_plateau.on_epoch_end(epoch, val_acc)
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 157.9386
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 2.0318
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 1.0920
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 1.2033
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.6684
# Seen so far: 51264 samples
# Training acc over epoch: 0.7695
# Validation acc: 0.8663
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.8257
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.9622
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3635
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4589
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3886
# Seen so far: 51264 samples
# Training acc over epoch: 0.8691
# Validation acc: 0.9047
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.7889
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3626
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2358
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3342
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.4172
# Seen so far: 51264 samples
# Training acc over epoch: 0.8941
# Validation acc: 0.9149
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.3026
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2140
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.6105
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2260
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2991
# Seen so far: 51264 samples
# Training acc over epoch: 0.9079
# Validation acc: 0.9261
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.2594
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3412
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.5681
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1328
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3502
# Seen so far: 51264 samples
# Training acc over epoch: 0.9164
# Validation acc: 0.9303
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.3116
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2824
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2597
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1618
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1655
# Seen so far: 51264 samples
# Training acc over epoch: 0.9222
# Validation acc: 0.9337
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.1948
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2724
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1675
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2590
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2679
# Seen so far: 51264 samples
# Training acc over epoch: 0.9279
# Validation acc: 0.9357
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.3089
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4099
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2281
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3907
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3347
# Seen so far: 51264 samples
# Training acc over epoch: 0.9314
# Validation acc: 0.9422
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.2105
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1028
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.0599
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2583
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1824
# Seen so far: 51264 samples
# Training acc over epoch: 0.9348
# Validation acc: 0.9445
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.0555
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2483
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1496
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1504
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1424
# Seen so far: 51264 samples
# Training acc over epoch: 0.9364
# Validation acc: 0.9470
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.2089
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1454
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2689
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3488
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1014
# Seen so far: 51264 samples
# Training acc over epoch: 0.9391
# Validation acc: 0.9455
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.2114
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1429
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2779
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.1347
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1274
# Seen so far: 51264 samples
# Training acc over epoch: 0.9438
# Validation acc: 0.9517
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.0798
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3344
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.1191
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3809
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1825
# Seen so far: 51264 samples
# Training acc over epoch: 0.9446
# Validation acc: 0.9520
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.2718
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.3123
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2260
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2294
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1654
# Seen so far: 51264 samples
# Training acc over epoch: 0.9450
# Validation acc: 0.9525
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.1446
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.1054
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.2141
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2059
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.1612
# Seen so far: 51264 samples
# Training acc over epoch: 0.9455
# Validation acc: 0.9522
