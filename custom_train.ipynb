# %%
{}
## Tensorflow Custom Training with Custom Callbacks
# Custom Training & Evaluation based on https://keras.io/guides/writing_a_training_loop_from_scratch/
# Reduce learning rate on plateau based on https://keras.io/api/callbacks/reduce_lr_on_plateau/
## Tutorial by Alexander Pelkmann 2021 
# Linkedin --> https://www.linkedin.com/in/alexander-pelkmann
# Github --> https://github.com/Pelk89

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

## Custom Modification: import custom reduce learning rate on plateau callback
from custom_callback import CustomReduceLRoP

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        logits = model(x, training=True)
        loss_value = loss_fn(y, logits)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    train_acc_metric.update_state(y, logits)
    return loss_value


@tf.function
def test_step(x, y):
    val_logits = model(x, training=False)
    val_acc_metric.update_state(y, val_logits)

# %%
# Instantiate an optimizer.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the training dataset.
batch_size = 64
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
# Get model
inputs = keras.Input(shape=(784,), name="digits")
x = layers.Dense(64, activation="relu", name="dense_1")(inputs)
x = layers.Dense(64, activation="relu", name="dense_2")(x)
outputs = layers.Dense(10, name="predictions")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# Instantiate an optimizer to train the model.
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
# Instantiate a loss function.
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# Prepare the metrics.
train_acc_metric = keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = keras.metrics.SparseCategoricalAccuracy()

# Prepare the training dataset.
batch_size = 64
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
# Reserve 10,000 samples for validation.
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(64)

# %%
## Custom Modification:

reduce_rl_plateau = CustomReduceLRoP(patience=10, 
                              verbose=1, 
                              optim_lr=optimizer.learning_rate, 
                              r_expo=True)

# %%
epochs = 15

## Custom Modification: Reset cooldown and wait timer for the callback
reduce_rl_plateau.train_begin()

for epoch in range(epochs):
    print("\nStart of epoch %d" % (epoch,))

    # Iterate over the batches of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        loss_value = train_step(x_batch_train, y_batch_train)

        # Log every 200 batches.
        if step % 200 == 0:
            print(
                "Training loss (for one batch) at step %d: %.4f"
                % (step, float(loss_value))
            )
            print("Seen so far: %d samples" % ((step + 1) * 64))

    # Display metrics at the end of each epoch.
    train_acc = train_acc_metric.result()
    print("Training acc over epoch: %.4f" % (float(train_acc),))

    # Reset training metrics at the end of each epoch
    train_acc_metric.reset_states()

    # Run a validation loop at the end of each epoch.
    for x_batch_val, y_batch_val in val_dataset:
        test_step(x_batch_val, y_batch_val)

    val_acc = val_acc_metric.result()
    val_acc_metric.reset_states()

 
    print("Validation acc: %.4f" % (float(val_acc),))

    ## Custom Modification: pass epoch and validation loss to the callback 
    reduce_rl_plateau.epoch_end(epoch, val_acc)
# Out:
# Start of epoch 0
# Training loss (for one batch) at step 0: 0.5175
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4139
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4269
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3291
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.5099
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.4428
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5165
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.6063
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.5550
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.4576
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.1807
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.6352
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4818
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.5059
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2939
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.4560
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.6742
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4792
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3918
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 1.3467
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.3637
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4968
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.6105
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4840
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.5016
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.4242
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4745
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4667
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3340
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.5587
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.3840
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5930
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.6141
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3669
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3893
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.4877
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.6476
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4687
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4622
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3412
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.4186
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.6089
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.7245
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.3171
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.2817
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.4143
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.4872
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3903
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.8272
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.4063
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.3818
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.2903
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.5599
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.8347
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.3370
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.6302
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.6213
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.5086
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4568
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.5180
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.7930
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5229
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.6171
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.5904
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.5636
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.4509
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.5226
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.3717
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.4618
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.7109
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.5050
# Seen so far: 64 samples
# Training loss (for one batch) at step 200: 0.9557
# Seen so far: 12864 samples
# Training loss (for one batch) at step 400: 0.4704
# Seen so far: 25664 samples
# Training loss (for one batch) at step 600: 0.2978
# Seen so far: 38464 samples
# Training loss (for one batch) at step 800: 0.6094
# Seen so far: 51264 samples
# Training acc over epoch: 0.8444
# Validation acc: 0.8570
